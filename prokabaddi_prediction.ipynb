# %%
import numpy as np

# %%
import pandas as pd

final_tmp=pd.read_csv('C:/Users/vicky/Desktop/prokabaddi/processed_data/final.csv')

# %%
final_tmp[final_tmp['season']=='season 1'].isnull().sum(axis = 0)
# Out:
# team1              0
# team2              0
# team1_score        0
# team2_score        0
# season             0
# matched_played1    0
# total_point1       0
# matched_played2    0
# total_point2       0
# Pld1               0
# W1                 0
# L1                 0
# D1                 0
# Pts1               0
# Pld2               0
# W2                 0
# L2                 0
# D2                 0
# Pts2               0
# dtype: int64

# %%
final_tmp[final_tmp['season']=='season 2'].isnull().sum(axis = 0)
# Out:
# team1              0
# team2              0
# team1_score        0
# team2_score        0
# season             0
# matched_played1    0
# total_point1       0
# matched_played2    0
# total_point2       0
# Pld1               0
# W1                 0
# L1                 0
# D1                 0
# Pts1               0
# Pld2               0
# W2                 0
# L2                 0
# D2                 0
# Pts2               0
# dtype: int64

# %%
final_tmp[final_tmp['season']=='season 5'].isnull().sum(axis = 0)
# Out:
# team1               0
# team2               0
# team1_score         0
# team2_score         0
# season              0
# matched_played1    13
# total_point1       13
# matched_played2    29
# total_point2       29
# Pld1                8
# W1                  8
# L1                  8
# D1                  8
# Pts1                8
# Pld2               11
# W2                 11
# L2                 11
# D2                 11
# Pts2               11
# dtype: int64

# %%
df_train=final_tmp[final_tmp['season']!='season 7']

# %%
len(df_train)
# Out:
# 466

# %%
df_train=df_train.dropna()

# %%
df_test=final_tmp[final_tmp['season']=='season 7']

# %%
df_test.columns
# Out:
# Index(['team1', 'team2', 'team1_score', 'team2_score', 'season',
#        'matched_played1', 'total_point1', 'matched_played2', 'total_point2',
#        'Pld1', 'W1', 'L1', 'D1', 'Pts1', 'Pld2', 'W2', 'L2', 'D2', 'Pts2'],
#       dtype='object')

# %%
df_test[['matched_played1', 'total_point1', 'matched_played2', 'total_point2',
       'Pld1', 'W1', 'L1', 'D1', 'Pts1', 'Pld2', 'W2', 'L2', 'D2', 'Pts2']]=None
# Out:
# C:\Users\vicky\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\vicky\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_test
# Out:
#                 team1                  team2  team1_score  team2_score  \
# 466       u.p. yoddha        bengal warriors         32.0         29.0
# 467   bengaluru bulls        tamil thalaivas         33.0         27.0
# 468  haryana steelers          puneri paltan         41.0         27.0
# 469     telugu titans        tamil thalaivas         35.0         30.0
# 470      dabang delhi   jaipur pink panthers         46.0         44.0
# 471   bengaluru bulls          patna pirates         40.0         39.0
# 472       u.p. yoddha          patna pirates         41.0         29.0
# 473   bengaluru bulls          telugu titans         40.0         39.0
# 474  haryana steelers           dabang delhi         47.0         25.0
# 475      dabang delhi        tamil thalaivas         50.0         34.0
# 476   bengal warriors          puneri paltan         42.0         39.0
# 477       u.p. yoddha  gujarat fortunegiants         33.0         26.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder 
  
le = LabelEncoder()

# %%
df_train['team1']= le.fit_transform(df_train['team1'])

# %%
df_train['team2']=le.transform(df_train['team2'])

# %%
df_test=df_test[df_test['team1']!='u.p. yoddha']

# %%
df_test=df_test[df_test['team2']!='u.p. yoddha']

# %%
df_test['team1']=le.transform(df_test['team1'])

# %%
df_test['team2']=le.transform(df_test['team2'])

# %%
df_train.drop('season',inplace=True,axis=1)

# %%
df_test.drop('season',inplace=True,axis=1)

# %%
df_test.head()
# Out:
#      team1  team2  team1_score  team2_score matched_played1 total_point1  \
# 467      1      8         33.0         27.0            None         None
# 468      4      7         41.0         27.0            None         None
# 469      9      8         35.0         30.0            None         None
# 470      2      5         46.0         44.0            None         None
# 471      1      6         40.0         39.0            None         None
#
#     matched_played2 total_point2  Pld1    W1    L1    D1  Pts1  Pld2    W2  \
# 467            None         None  None  None  None  None  None  None  None
# 468            None         None  None  None  None  None  None  None  None
# 469            None         None  None  None  None  None  None  None  None
# 470            None         None  None  None  None  None  None  None  None
# 471            None         None  None  None  None  None  None  None  None
#
#        L2    D2  Pts2
# 467  None  None  None
# 468  None  None  None
# ...

# %%
df_train.columns
# Out:
# Index(['team1', 'team2', 'team1_score', 'team2_score', 'matched_played1',
#        'total_point1', 'matched_played2', 'total_point2', 'Pld1', 'W1', 'L1',
#        'D1', 'Pts1', 'Pld2', 'W2', 'L2', 'D2', 'Pts2'],
#       dtype='object')

# %%
df_train_x=df_train[['team1', 'team2', 'team1_score', 'team2_score']]
df_train_y=df_train[['matched_played1',
       'total_point1', 'matched_played2', 'total_point2', 'Pld1', 'W1', 'L1',
       'D1', 'Pts1', 'Pld2', 'W2', 'L2', 'D2', 'Pts2']]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor(random_state = 0)

# %%
regressor.fit(df_train_x, df_train_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
df_test[['matched_played1',
       'total_point1', 'matched_played2', 'total_point2', 'Pld1', 'W1', 'L1',
       'D1', 'Pts1', 'Pld2', 'W2', 'L2', 'D2', 'Pts2']]=regressor.predict(df_test[['team1', 'team2', 'team1_score', 'team2_score']])

# %%
df_test['team1']=le.inverse_transform(df_test['team1'])

# %%
df_test['team2']=le.inverse_transform(df_test['team2'])

# %%
df_test['total_point1'].max()
# Out:
# 1050.0

# %%
df_test[df_test['total_point1']==1050]
# Out:
#              team1                  team2  team1_score  team2_score  \
# 483  puneri paltan  gujarat fortunegiants         43.0         33.0
#
#      matched_played1  total_point1  matched_played2  total_point2  Pld1    W1  \
# 483             26.0        1050.0             22.0         689.0  22.0  10.0
#
#       L1   D1  Pts1  Pld2   W2    L2   D2  Pts2
# 483  7.0  5.0  71.0  22.0  8.0  11.0  3.0  57.0

# %%
## from above we can predict that puneri paltan have score more points

# %%
df_test
# Out:
#                 team1                  team2  team1_score  team2_score  \
# 467   bengaluru bulls        tamil thalaivas         33.0         27.0
# 468  haryana steelers          puneri paltan         41.0         27.0
# 469     telugu titans        tamil thalaivas         35.0         30.0
# 470      dabang delhi   jaipur pink panthers         46.0         44.0
# 471   bengaluru bulls          patna pirates         40.0         39.0
# 473   bengaluru bulls          telugu titans         40.0         39.0
# 474  haryana steelers           dabang delhi         47.0         25.0
# 475      dabang delhi        tamil thalaivas         50.0         34.0
# 476   bengal warriors          puneri paltan         42.0         39.0
# 478     patna pirates        tamil thalaivas         51.0         25.0
# 479           u mumba          telugu titans         41.0         27.0
# 480   bengal warriors                u mumba         29.0         26.0
# ...
